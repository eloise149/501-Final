# %% [markdown]
# #**Introduction to Git and GitHub**
# After creating an organized file structure for your research, you may want to share your work with colleagues.
#
# The most transparent and organized way to do so is through GitHub, a cloud-based version control platform that will host your entire project as a repository, or repo for short.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# As its name suggest, GitHub is hub for projects managed with Git: a program used to record all changes made to a project as a comprehensive history.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Therefore, to use GitHib let's first learn the fundamentals of Git.

# %% [markdown]
# #**Introduction to Git subcommands**
# Git is a UNIX command-line program; and by default, Google Colab notebooks run all code within a Python 3 runtime environment. Therefore, to use UNIX programs instead of Python code, users need to specify how they want the contents of a code block run.
#
# One way this can be achived is by starting each cell block with `%%bash` .
# Here, the name Bash refers to a type of Unix shell.

# %% [markdown]
# ##**Run the `git help` command in a Bash environment.**

# %%
# %%bash
# git help
# Out:
# usage: git [--version] [--help] [-C <path>] [-c <name>=<value>]
#            [--exec-path[=<path>]] [--html-path] [--man-path] [--info-path]
#            [-p | --paginate | -P | --no-pager] [--no-replace-objects] [--bare]
#            [--git-dir=<path>] [--work-tree=<path>] [--namespace=<name>]
#            [--super-prefix=<path>] [--config-env=<name>=<envvar>]
#            <command> [<args>]
#
# These are common Git commands used in various situations:
#
# start a working area (see also: git help tutorial)
#    clone     Clone a repository into a new directory
#    init      Create an empty Git repository or reinitialize an existing one
#
# work on the current change (see also: git help everyday)
#    add       Add file contents to the index
#    mv        Move or rename a file, a directory, or a symlink
#    restore   Restore working tree files
#    rm        Remove files from the working tree and from the index
#
# examine the history and state (see also: git help revisions)
# ...

# %% [markdown]
# Notice that the `git help` subcommand only prints information about other Git subcommands. These commands are what we will use to create our first repository.
#
# To start, let's clear out the default current directory, `/content`,  that Google Colab puts us into every time we open a notebook.

# %% [markdown]
# ##**Run commands to prepare Google Colab for usage with Git.**

# %% [markdown]
# ###**Remove the default `sample_data` folder from the `/content` directory.**
#
# Here, we use the `rm` (remove) command with the `-r` (recursive) option.

# %%
# %%bash
# rm -r sample_data

# %% [markdown]
# Additionally, we must create a special file called `.gitignore` to prevent the default Google Colab `.config` folder from interfering with our Git repository.

# %% [markdown]
# ###**Create a `.gitignore` file that tells Git to ignore the hidden `.config` folder.**

# %%
# %%bash
# cat > .gitignore
# .*
# .gitignore

# %% [markdown]
# Finally, before using Git we must specify who we are. This is to ensure that when multiple people are making changes to a Git project, everyone knows who made what changes.

# %% [markdown]
# ##**Set an identity with `git config`.**
#
# This is typically performed exactly as follows, with an email or name written within the double-quotation marks.
#
#
# For the sake of this tutorial, we will use a dummy email and name.

# %%
# %%bash
# git config --global user.email "you@example.com"
# git config --global user.name "Your Name"

# %% [markdown]
# Now we're ready to convert the current directory into a Git repository.

# %% [markdown]
# ##**Convert `/content` into a Git repository with `git init`.**

# %%
# %%bash
# git init
# Out:
# Initialized empty Git repository in /content/.git/
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>

# %% [markdown]
# In addition to the message output above, you can confirm that the current directory is a Git repository by running the `ls` (list) command with the `-a` (all) option to display eveything within a directory, including hidden folders like `.git`.

# %%
# %%bash
# ls -a
# Out:
# .
# ..
# .config
# .git
# .gitignore

# %% [markdown]
# The presence of the `.git` folder confirms that we are inside a Git repository. From here, you can visualize the current version of the repository as a node like below.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Then, as we make changes to this repository, its history will be recorded as a series of nodes.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Note that each of the above nodes represents a distinct version of the repository. This is because Git does not continually save every little change to your repository. Instead changes must be saved (aka. commmited) to produce distinct versions.
#
# You may have done something similar before with Microsoft Word documents named as follows:
#
# *   Manuscript.docx
# *   Manuscript2.docx
# *   Manuscript3.docx
# *   ManuscriptFinal.docx
# *   ManuscriptFinal_Final.docx
# *   ManuscriptFinal_Final_Final.docx
#
# However, instead of filling up your folder with a slew of document versions with potentially ambiguous names, Git will only store the latest version of the file while enabling you to restore previous versions should you need to.
#
# To demonstrate this, let us make changes to Git repository we have just made.

# %% [markdown]
# ##**Make arbritrary changes to the Git repository with various Unix commands.**
#
# The command below will produce a text file.

# %%
# %%bash
# cat > textFile.txt
# This is a text file.
# It has the .fasta extension.

# %% [markdown]
# Now that we are satisfied with our changes let's save our progress as a new version. To do so, we use the `git add` and `git commit` subcommands.
#
# `git add` will be used first to "add" all new files and/or subdirectories to an imaginary staging area where changes can be reviewed. While no files or subdirectories are actually moved, this will mark them as visible to the `git commit` subcommand.
#
# Then, once you are satisfied with all the changes, you can commit to the changes with `git commit`, creating a new version of your repository.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**Add one or more files to the staging area with `git add`.**
#
# Here the `-A`/`--all`/`--no-ignore-removal` option is used to track all new, modified, and deleted files.

# %%
# %%bash
# git add -A

# %% [markdown]
# You can confirm that a new file was added to the staging area with the command below.

# %%
# %%bash
# git diff --name-only --cached
# Out:
# textFile.txt

# %% [markdown]
# ##**Commit changes in the staging area with `git commit`.**
#
# In addition to saving a new version of your repository, it is also standard practice to label your new version with a short message describing what has changed.
#
# This is performed with the `-m` (message) option followed by a description bounded by quotation marks.

# %%
# %%bash
# git commit -m "Added a text file."
# Out:
# [master (root-commit) 147b272] Added a text file.
#  1 file changed, 2 insertions(+)
#  create mode 100644 textFile.txt

# %% [markdown]
# Congratulations, you have made your first Git commit and are ready to make more!
#
# We can do so by repeating the steps above.
# For example, if we check the file above, it contained an error.

# %%
# %%bash
# cat textFile.txt
# Out:
# This is a text file.
# It has the .fasta extension.

# %% [markdown]
# Instead of ending in `.fasta`, our text file ends in `.txt` . We can overwrite our file as follows:

# %%
# %%bash
# cat > textFile.txt
# This is a text file.
# It has the .txt extension.

# %% [markdown]
# Next, we can save our changes by using `git add` and `git commit` again.

# %%
# %%bash
# git add -A
# git commit -m "Fixed the extension error in textFile.txt."
# Out:
# [master f8cffa6] Fixed the extension error in textFile.txt.
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %% [markdown]
# #**Moving from Git to GitHub**
#
# So far, we have shown how to manage a Git repository within a notebook environment. However, to share our projects with colleagues we must post our projects somewhere online. The premier website for this is GitHub.com .
#
# We will move our Git repository to GitHub as follows.

# %% [markdown]
# ##**Create a GitHub account through the following link.**

# %% [markdown]
# https://github.com/signup?ref_cta=Sign+up&ref_loc=header+logged+out&ref_page=%2F&source=header-home

# %% [markdown]
# ##**Go to your GitHub homepage by opening the link below.**

# %% [markdown]
# https://github.com/

# %% [markdown]
# ##**Create a new repository by clicking the green _New_ button in the left panel.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**Type a name into the `Repository name` field and select any other options below according to your preferences.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**Click the green _Create repository_ button at the bottom of the page to create a new repository.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# After clicking the button, you will be presented with an empty GitHub repo. **Be sure that `Add a README file` is unchecked or else you will experience issues pushing your local Git repoisitory to a non-empty GitHub repo.**

# %% [markdown]
# ##**Click the white _SSH_ button to change the link type from HTTPS to SSH.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**Click the white copy button next to the header below.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**Paste the above code below to push the repository in this notebook to GitHub.**
#
# Do not forget to add the `%%bash` header to use `git` subcommands.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# As shown above, attempting to run this code for the first time will produce an error. This is because GitHub was unable to verify who you are just from the notebook commands alone.
#
# As such, we will come back to this command later once we learn about GitHub key verification.

# %% [markdown]
# #**Following GitHub security protocol with SSH keys**
#
# At the moment, your GitHub account is like a room with a locked door without any keyholes.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Currently, there is no easy way to access what's inside.
#
# Therefore, what we will explain here is how to add a keyhole to your GitHub account and produce a key that can unlock it.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# One way to achieve this is with Secure Shell (SSH) keys. This method will involve both a public key (the keyhole) and a private key (your key for it). To create these, run the Unix commands below.

# %% [markdown]
# ###**Generate a private SSH key for reuse.**
#
# Just like with physical keys, it is good practice to label them in case you have a lot of them. Here, you can label your keys with a comment using the `-C` option. It is standard to label keys by email address to easily distinguish who you will give access to your GitHub repos.

# %%
# %%bash
# ssh-keygen -t ed25519 -C '[YOUR_EMAIL_HERE]' -f ~/.ssh/id_ed25519 -P ''
# cat > ~/.ssh/config
# Host *
#   AddKeysToAgent yes
#   IdentityFile ~/.ssh/id_ed25519
# Out:
# Generating public/private ed25519 key pair.
# Your identification has been saved in /root/.ssh/id_ed25519
# Your public key has been saved in /root/.ssh/id_ed25519.pub
# The key fingerprint is:
# SHA256:oJcj+KFWqpaCAdv+aPwOaTQ8uGlvGrAlB4l1eFGzPfg [YOUR_EMAIL_HERE]
# The key's randomart image is:
# +--[ED25519 256]--+
# |  ..ooo          |
# |.o...  =         |
# |+  .  + o        |
# |.+ . . + .       |
# |=oO = + E        |
# |+O.O + .         |
# |=*O .            |
# |+**+             |
# |+o+=+            |
# +----[SHA256]-----+
# Created directory '/root/.ssh'.

# %% [markdown]
# After running this code-block, a "key" (private key) will be created at the location `~/.ssh/id_ed25519`. While the contents of this file should be kept secret, for our example here you can view the key by running the code block below.

# %%
# %%bash
# cat ~/.ssh/id_ed25519
# Out:
# -----BEGIN OPENSSH PRIVATE KEY-----
# b3BlbnNzaC1rZXktdjEAAAAABG5vbmUAAAAEbm9uZQAAAAAAAAABAAAAMwAAAAtzc2gtZW
# QyNTUxOQAAACDvd11ietigR7mDkkZ0brMZ/0mx/JOsHlsdIQZL5VDRagAAAJhRzhkGUc4Z
# BgAAAAtzc2gtZWQyNTUxOQAAACDvd11ietigR7mDkkZ0brMZ/0mx/JOsHlsdIQZL5VDRag
# AAAEBPWvq3HtLzOfzA7OSAtUlO7Knac3JegB8pdvUvuHMs4u93XWJ62KBHuYOSRnRusxn/
# SbH8k6weWx0hBkvlUNFqAAAAEVtZT1VSX0VNQUlMX0hFUkVdAQIDBA==
# -----END OPENSSH PRIVATE KEY-----

# %% [markdown]
# Like real keys, you will want to use your digital "key" (private key) multiple times. To do so, whenever you log into a new Colab notebook, you can create the file above as shown below. Here, a generated "key" (private key) is pasted below the code
# ```
# %%bash
# cat > ~/.ssh/id_ed25519
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Unfortunately, doing it in this manner will leave your "key" (private key) exposed so be sure to remove it from any code blocks before sharing your notebook.
#
# Regardless of whichever method you use to add a "key" (private key) to your notebook, your next step will be to install it with the following code-block.

# %%
# %%bash
# eval "$(ssh-agent -s)"
# ssh-add ~/.ssh/id_ed25519
# Out:
# Agent pid 822
# Identity added: /root/.ssh/id_ed25519 ([YOUR_EMAIL_HERE])

# %% [markdown]
# Now that a "key" (private key) has been installed, the next step is to generate a matching keyhole and register it to your GitHub account.

# %% [markdown]
# ###**Generate and register a "keyhole" (public key).**

# %%
# %%bash
# cat ~/.ssh/id_ed25519.pub
# Out:
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAIO93XWJ62KBHuYOSRnRusxn/SbH8k6weWx0hBkvlUNFq [YOUR_EMAIL_HERE]

# %% [markdown]
# Next, add this public SSH key to your GitHub account here:
# https://github.com/settings/keys
#
# Once at this page, click on the green button circled in red below:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Then, give your new keyhole a name under **Title**, copy the text output the last code block into **Key**, and click the `Add SSH key` button to finialize your keyhole.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Finally, you can verify that your key-keyhole pair works by running the command below.

# %%
# %%bash
# ssh -o "StrictHostKeyChecking no" -T git@github.com | exit 0
# Out:
# ...
# git@github.com: Permission denied (publickey).

# %% [markdown]
# If it does work, you will receive a message that includes the phrase `You've successfully authenticated`.
#
# Note that whenever you restart your notebook, your "key" (private key) will be deleted. Therefore to retain access to your GitHub account from Colab you have two options: either manually re-add your "key" (private key) or generate a new key and register a new keyhole on GitHub. If you choose the later be sure to delete old keyholes from the https://github.com/settings/keys page to prevent your account from accumulating unnecessary keyholes like follows:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**Moving from Git to GitHub (continued)**
#
# Now that we can access the GitHub repo from Google Colaboratory, we can rerun the code block copied earlier.

# %% [markdown]
# ##**Paste the code from the previous section to push the repository in this notebook to GitHub.**
#
# Do not forget to add the `%%bash` header to use `git` subcommands.

# %%
# %%bash
# git remote add origin git@github.com:CynthiaFlaire/temp.git
# git branch -M main
# git push -u origin main
# Out:
# error: remote origin already exists.
# git@github.com: Permission denied (publickey).
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-21-0d02d42c5f4f> in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('bash', '', 'git remote add origin git@github.com:CynthiaFlaire/temp.git\ngit branch -M main\ngit push -u origin main\n')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
# ...

# %% [markdown]
# Congratulations, you have successfully moved your Git repository to GitHub! Upon refreshing the page, you should now see the text file created earlier.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Additionally you may ignore the output messages `fatal: remote origin already exists.` and `Warning: Permanently added the ECDSA host key...`as these will not affect your GitHub repo.
#
# Next, we can update this GitHub repo with the following commands.

# %% [markdown]
# ##**Make arbritrary changes to the Git repository with various Unix commands.**
#
# The commands below will create a new directory and move the previously made text file into it.

# %%
# %%bash
# mkdir textFiles
# mv textFile.txt textFiles/textFile.txt

# %% [markdown]
# ##**Add files to the notebook staging area with `git add` and confirm them with `git diff`.**

# %%
# %%bash
# git add -A
# git diff --name-only --cached

# %% [markdown]
# ##**Commit the changes to create a new version of the Git repository with `git commit`.**

# %%
# %%bash
# git commit -m "Created a directory for the text file."

# %% [markdown]
# ##**Push the changes to the online GitHub repo with `git push`.**

# %%
# %%bash
# git push

# %% [markdown]
# After running this command, you can check your GitHub repo to see that the text file has been moved into the new directory.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**Working with other peoples' repositories**
#
# In addition to uploading your own Git repositories to GitHub, it is also possible to download entire GitHub repos to your notebook. To do so, you will need a URL link to the repository.

# %% [markdown]
# ##**Visit the repository of interest.**

# %% [markdown]
# https://github.com/mwaskom/seaborn-data.git

# %% [markdown]
# ##**Click the green _Code_ button to open up a small panel.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**Click the copy button to copy the HTTPS link to the repository.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**Paste the link as an argument to the `git clone` subcommand.**

# %%
# %%bash
# git clone https://github.com/mwaskom/seaborn-data.git

# %% [markdown]
# You can now check the left panel to see that entire GitHub repo was copied into the `seaborn-data` directory. Note that using the HTTPS link will only work for public GitHub repos.
#
# If the repository you are attempting to clone is private, you will instead receive the following error and will have to request set up public & private SSH keys from the repo owner.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Additionally, you will need to instead copy the SSH link under the second tab.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Finally, as you have reached the end of our tutorial, note that we have only scratched the surface of Git & GitHub's power for facilitating transparent, reproducible, and collaborative research.
#
# To learn more, you are encouraged to look up Git and GitHub tutorials online covering topics such as:
#
# *   Branching
# *   Merging
# *   Forking GitHub repos
# *   GitHub pull-requests
# *   etc.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**Hands-on Assignment 2: Sharing your projects on GitHub**

# %% [markdown]
# ##**Introduction**
#
# Keeping organized is an important aspect of efficient research. From saving time to preventing confusion with your collaborators, documenting and organizing one's project files is essential for producing transparent and reproducible results.
#
# To this end, README files can be used to help users of your research (including your future self) to navigate through the many files you produce by providing descriptions for all files and folders stored in its directory.
#
# As such, today you will produce an organized GitHub repo with README files to practice sharing the results of your research.

# %% [markdown]
# ##**Instructions**
#
# In your own Google Colab notebook, use the commands presented both here and in the previous sections to produce your own GitHub repo with the structure shown below. You will be graded based on whether your repo has the correct structure and whether the `README.txt` files contain descriptions of each directory's contents. As such, please submit your Google Colab notebook with a link to the GitHub repo it produced in the <font color='red'>Add the link to your GitHub repo here.</font> text box.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Here, all directories are represented by large gray boxes, subdirectories are blue labels, README files are green labels, and all other files are  yellow-orange labels.
#
# Additionally, the `startingData` directory stores all data files that serve as input to analysis, the `code` directory stores code and related files used during analysis, the `results` directory stores files created during and after the analysis, and the `figures` directory stores your project's figures.
#
# As before, all files should be empty and only be named after their respective labels in the schematic above. Below is a refresher on Unix commands to do this.

# %% [markdown]
# Use the `%%bash` header plus the following Unix commands to navigate your Colab notebook's file structure:
#
# *   `ls` : list out the files and subdirectories in the current directory
# *   `cd DIRECTORY` : change the current directory to DIRECTORY, resets to the default `/content` folder with every new code-block
# *   `cd ..` : to return to the parent DIRECTORY
# *   `cat > FILE` : create an empty file named FILE
# *   `mkdir DIRECTORY` : create a new directory named DIRECTORY

# %% [markdown]
# ##**Steps**

# %% [markdown]
# Let's start by removing the `sample_data` directory from the `/content` folder.

# %%
# %%bash
# rm -r sample_data

# %% [markdown]
# Then, let's create the `.gitignore` file as shown in the tutorial.

# %%
# %%bash
# cat > .gitignore
# .*
# .gitignore

# %% [markdown]
# Next, set your identity with `git config`.

# %%
# %%bash
# git config --global user.email "lliu8815@usc.edu"
# git config --global user.name "eloise149"

# %% [markdown]
# You are now ready to turn the `/content` folder into a Git repository. Do so in the code block below.

# %%
# %%bash
# git init
# Out:
# Reinitialized existing Git repository in /content/.git/

# %% [markdown]
# Now that the `/content` folder is a Git repository, copy your code from the previous assignment to create the organized repository structure. Use one code-block for each step as you have done previously.

# %%
# %%bash
# mkdir -p content/Chapter1 content/Chapter2 content/Chapter3

# %%
# %%bash
# cd content/Chapter1
# mkdir startingData code results figures

# %%
# %%bash
# touch content/README.md

# %%
# %%bash
# touch content/Chapter1/README.md

# %%
# %%bash
# touch content/Chapter1/startingData/README.md

# %%
# %%bash
# touch content/Chapter1/code/README.md

# %%
# %%bash
# touch content/Chapter1/results/README.md

# %%
# %%bash
# touch content/Chapter1/figures/README.md

# %%
# %%bash
# touch content/Chapter1/startingData/case.fq.gz

# %%
# %%bash
# touch content/Chapter1/startingData/control.fq.gz

# %%
# %%bash
# touch content/Chapter1/startingData/reference.fq.gz

# %%
# %%bash
# touch content/Chapter1/startingData/reference2.gtf

# %%
# %%bash
# touch content/Chapter1/startingData/metadata.csv

# %%
# %%bash
# touch content/Chapter1/code/script.py

# %%
# %%bash
# touch content/Chapter1/code/analysis.ipynb

# %%
# %%bash
# touch content/Chapter1/code/visualization.ipynb

# %%
# %%bash
# touch content/Chapter1/code/specifications.mplstyle

# %%
# %%bash
# touch content/Chapter1/results/qualityReport.html

# %%
# %%bash
# touch content/Chapter1/results/intermediateFile.bam

# %%
# %%bash
# touch content/Chapter1/results/tabularData.csv

# %%
# %%bash
# touch content/Chapter1/figures/Figure1.pdf

# %%
# %%bash
# touch content/Chapter1/figures/Figure2.pdf

# %% [markdown]
# Once you have the correct stucture, use `git add -A` to add all your changed to the imaginary staging area.

# %%
# %%bash
# git add -A

# %% [markdown]
# :Then, use `git commit -m` as shown in the tutorial to commit the changes you have made.

# %%
# %%bash
# git commit -m "Structure built."

# %% [markdown]
# With your local Git repository now complete, follow the next steps to push it to GitHub. Start by logging into GitHub and creating an empty GitHub repo with your GitHub account. It can be named whatever you want it to be.

# %% [markdown]
# Next, create a set of public & private SSH keys to access your GitHub repo from this Colab notebook. This will involve following the steps outlined in the `Following GitHub secruity protocol with SSH keys` section. You may use multiple code-blocks to do this.

# %% [markdown]
# Generate a new private key ("key").

# %%
# %%bash
# ssh-keygen -t ed25519 -C '[lliu8815@usc.edu]' -f ~/.ssh/id_ed25519 -P ''
# cat > ~/.ssh/config
# Host *
#   AddKeysToAgent yes
# Out:
# Generating public/private ed25519 key pair.
# Your identification has been saved in /root/.ssh/id_ed25519
# Your public key has been saved in /root/.ssh/id_ed25519.pub
# The key fingerprint is:
# SHA256:VvIb/Mno5C6CFiR8qQontKMGdgD0PMK29lD0qGFbWZc [lliu8815@usc.edu]
# The key's randomart image is:
# +--[ED25519 256]--+
# |.. . . ..        |
# |o + = .E         |
# |.B O o  . .      |
# |oo@ =    =       |
# |.*o=    S +      |
# |=+=..  .   * .   |
# |=+o. o    + +    |
# |o.  o . .+       |
# |.  .   . o+      |
# +----[SHA256]-----+
# Created directory '/root/.ssh'.

# %% [markdown]
# Install the private key ("key").

# %%
# %%bash
# eval "$(ssh-agent -s)"
# ssh-add ~/.ssh/id_ed25519
# Out:
# Agent pid 4572
# Identity added: /root/.ssh/id_ed25519 ([lliu8815@usc.edu])

# %% [markdown]
# Generate and register a public key ("keyhole").

# %%
# %%bash
# cat ~/.ssh/id_ed25519.pub
# Out:
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAIKiLICCh8O8MKLDVcNbmlnidmhM8KoOPlenonx30+Q1p [lliu8815@usc.edu]

# %% [markdown]
# Once you connected to GitHub, obtain its SSH link like shown in the picture below.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Finally, fill in the ■■■■■■■■■■■■ with your GitHub repo's SSH link and run the code-block below to upload your Git repository to GitHub.
#
# If you encounter the error, `fatal: remote origin already exists.`, replace `git remote add origin` with `git remote set-url origin`.

# %%
# %%bash
# git remote set-url origin https://github.com/eloise149/Lab09.git
# git branch -M main
# git push -u origin main

# %% [markdown]
# Congratulations! Your organized repository structure is now saved online and can be easily shared with via web browser link! As a finishing touch, paste the link to your repository in the text box below:

# %% [markdown]
# <font color='red'>Add the link to your GitHub repo here.</font>

# %% [markdown]
# https://github.com/eloise149/temp.git

# %% [markdown]
# ##**Rubric (10 points)**

# %% [markdown]
# **3 points**
#
# You successfully commited a change to your notebook's local Git repository.
#
# ---
#
# **1 point**
#
# A GitHub repository, filled or empty, was created and a link to it was provided in the <font color='red'>Add the link to your GitHub repo here.</font>  text box.
#
# ---
#
# **3 points**
#
# Access to your GitHub account was successfully authenticated and you received the "You've successfully authenticated, but GitHub does not provide shell access." message.
#
# ---
#
# **3 points**
#
# Your linked GitHub repository has the correct or nearly correct structure as presented in the above schematic.
