# %% [markdown]
# #**Introduction to DataFrame Manipulation with Pandas**

# %% [markdown]
# In the previous assignment, you learned the basics of Python data structures and functions as well as how libraries extend the Python language with new data structures and methods.
#
# Libraries are collections of software that can extend the functionality of Python. One we will use extensively in this course is Pandas, a library that facilitates the manipulation and analysis of tabular datasets.
#
# In this lab we will introduce additional ways Pandas DataFrames are manipulated to reorganize one's tabular data into formats suitable for later data visualization and statistical analysis.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**Extending Python with libraries**

# %% [markdown]
# ## **Import the Pandas library.**

# %%
import pandas as pd

# %% [markdown]
# Notice that the ```as``` statement is used to define an alias for Pandas. ```pd``` is the standard abbreviation for Pandas.

# %% [markdown]
# ##**Pandas' DataFrame**

# %% [markdown]
# **DataFrames**
#
# Pandas represents tabular datasets as DataFrames which are akin to tables in Excel spreadsheets.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**Replicate the above Excel table as a Pandas DataFrame.**

# %% [markdown]
# **First, store the contents of the DataFrame in a dictionary of lists where each key is a column name and each list are the column's contents.**

# %%
columns = {'columnOne': ['cell1','cell2','cell3','cell4'], 'columnTwo': [1,2,3,4]}
columns
# Out:
# {'columnOne': ['cell1', 'cell2', 'cell3', 'cell4'], 'columnTwo': [1, 2, 3, 4]}

# %% [markdown]
# **Next, use dot notation to access the DataFrame() function within the Pandas library and pass it the columns as an argument.**

# %%
pd.DataFrame(columns)
# Out:
#   columnOne  columnTwo
# 0     cell1          1
# 1     cell2          2
# 2     cell3          3
# 3     cell4          4

# %% [markdown]
# **Finally, save the new DataFrame as a variable.**

# %%
df = pd.DataFrame(columns)
df
# Out:
#   columnOne  columnTwo
# 0     cell1          1
# 1     cell2          2
# 2     cell3          3
# 3     cell4          4

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **Similar to dictionaries, you can access columns of a DataFrame by calling specific keys, in this case, the names of each column.**

# %%
df['columnOne']
# Out:
# 0    cell1
# 1    cell2
# 2    cell3
# 3    cell4
# Name: columnOne, dtype: object

# %%
df['columnTwo']
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: columnTwo, dtype: int64

# %% [markdown]
# **Furthermore, multiple columns can be selected by calling a list of keys.**
#
# Notice how the double-brackets denote using a list as an index.

# %%
df[['columnOne','columnTwo']]
# Out:
#   columnOne  columnTwo
# 0     cell1          1
# 1     cell2          2
# 2     cell3          3
# 3     cell4          4

# %% [markdown]
# ###**Produce a Pandas DataFrame with an NaN value based on the Excel table below.**

# %% [markdown]
# Similar to Excel tables, sometimes you will encounter empty cells. In Pandas DataFrames, these are represented by special floats called NaN (Not a Number) values.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
columns = {'columnOne': ['cell1','cell2','cell3','cell4'], 'columnTwo': [1,2,float('nan'),4]}
df = pd.DataFrame(columns)
df
# Out:
#   columnOne  columnTwo
# 0     cell1        1.0
# 1     cell2        2.0
# 2     cell3        NaN
# 3     cell4        4.0

# %% [markdown]
# Here, the float() function was used to force the string ```'nan'``` into its special float form.

# %% [markdown]
# ##**Pandas' Series**

# %% [markdown]
# **Series**
#
# Pandas represents the columns of DataFrames as series, which are akin to columns of an Excel table. They can be accessed by indexing a DataFrame with its columns.

# %%
df['columnOne']
# Out:
# 0    cell1
# 1    cell2
# 2    cell3
# 3    cell4
# Name: columnOne, dtype: object

# %%
type(df['columnOne'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ##**Pandas functions**
#
# The Pandas library includes both general functions and DataFrame-associated functions (aka. Methods). Below are a few examples of the Pandas functions you will use in this course. Like above, they can be accessed using dot notation.

# %% [markdown]
# **Pandas' isnull() function checks whether the input is an NaN value and returns True or False.**

# %%
NaNValue = float('nan')
pd.isnull(NaNValue)
# Out:
# True

# %% [markdown]
# **Pandas' read_csv() function enables users to import .csv (comma-seperated values) and .tsv (tab-seperated values) files as DataFrames.**
#
# This function accepts both file paths (ex./content/drive/MyDrive/myTable.csv) and direct-download URLs.

# %%
antBrainCellsDF = pd.read_csv('https://zenodo.org/record/4579911/files/00_RKG_MS_WG_RawCCData.csv?download=1')

# %% [markdown]
# Since this DataFrame has several hundred rows, calling its name will only display the very beginning and end of the DataFrame.

# %%
antBrainCellsDF
# Out:
#      Unnamed: 0  Superfamily      Family       Genus      species  \
# 0             1  Formicoidea  Formicidae  Acromyrmex   versicolor
# 1             2  Formicoidea  Formicidae  Acromyrmex   versicolor
# 2             5  Formicoidea  Formicidae  Acromyrmex   versicolor
# 3             6  Formicoidea  Formicidae  Acromyrmex   versicolor
# 4             7  Formicoidea  Formicidae  Acromyrmex   versicolor
# ..          ...          ...         ...         ...          ...
# 517         710      Apoidea      Apidae    Xylocopa  californica
# 518         712      Apoidea      Apidae    Xylocopa  californica
# 519         725      Apoidea      Apidae    Xylocopa  californica
# 520         729      Apoidea      Apidae    Xylocopa  californica
# 521         735      Apoidea      Apidae    Xylocopa  californica
#
#      TotalBodyMass_mg  HeadWidth_mm  BrM_mg_scaled     Nuclei     StDev  \
# 0               16.38          2.08           0.08    21578.0    8067.0
# ...

# %% [markdown]
# **Pandas' head() function can be used to view just the beginning portions of a DataFrame.**

# %%
antBrainCellsDF.head()
# Out:
#    Unnamed: 0  Superfamily      Family       Genus     species  \
# 0           1  Formicoidea  Formicidae  Acromyrmex  versicolor
# 1           2  Formicoidea  Formicidae  Acromyrmex  versicolor
# 2           5  Formicoidea  Formicidae  Acromyrmex  versicolor
# 3           6  Formicoidea  Formicidae  Acromyrmex  versicolor
# 4           7  Formicoidea  Formicidae  Acromyrmex  versicolor
#
#    TotalBodyMass_mg  HeadWidth_mm  BrM_mg_scaled   Nuclei    StDev       CV
# 0             16.38          2.08           0.08  21578.0   8067.0  0.37385
# 1             13.07          2.08           0.10  22208.0   6782.0  0.30539
# 2              5.06          1.99           0.09  55575.0  19973.0  0.35938
# 3              7.00          2.10           0.09  60288.0  15020.0  0.24914
# 4              5.80          1.88           0.15  66463.0  21686.0  0.32629

# %% [markdown]
# Additionally, the head() fuction can be passed an integer argument to specify the number of lines to display.

# %%
antBrainCellsDF.head(10)
# Out:
#    Unnamed: 0  Superfamily      Family       Genus     species  \
# 0           1  Formicoidea  Formicidae  Acromyrmex  versicolor
# 1           2  Formicoidea  Formicidae  Acromyrmex  versicolor
# 2           5  Formicoidea  Formicidae  Acromyrmex  versicolor
# 3           6  Formicoidea  Formicidae  Acromyrmex  versicolor
# 4           7  Formicoidea  Formicidae  Acromyrmex  versicolor
# 5           8  Formicoidea  Formicidae  Acromyrmex  versicolor
# 6           9  Formicoidea  Formicidae  Acromyrmex  versicolor
# 7          10  Formicoidea  Formicidae  Acromyrmex  versicolor
# 8          11  Formicoidea  Formicidae  Acromyrmex  versicolor
# 9          12  Formicoidea  Formicidae  Acromyrmex  versicolor
#
#    TotalBodyMass_mg  HeadWidth_mm  BrM_mg_scaled   Nuclei    StDev       CV
# 0             16.38          2.08           0.08  21578.0   8067.0  0.37385
# 1             13.07          2.08           0.10  22208.0   6782.0  0.30539
# ...

# %% [markdown]
# **Pandas' tail() function can be used to view just the ending portions of a DataFrame.**

# %%
antBrainCellsDF.tail(10)
# Out:
#      Unnamed: 0 Superfamily  Family     Genus      species  TotalBodyMass_mg  \
# 512         699     Apoidea  Apidae  Xylocopa  californica            714.70
# 513         700     Apoidea  Apidae  Xylocopa  californica            804.40
# 514         702     Apoidea  Apidae  Xylocopa  californica            833.80
# 515         703     Apoidea  Apidae  Xylocopa  californica            776.50
# 516         706     Apoidea  Apidae  Xylocopa  californica            905.00
# 517         710     Apoidea  Apidae  Xylocopa  californica            421.90
# 518         712     Apoidea  Apidae  Xylocopa  californica            753.30
# 519         725     Apoidea  Apidae  Xylocopa  californica            800.37
# 520         729     Apoidea  Apidae  Xylocopa  californica            802.30
# 521         735     Apoidea  Apidae  Xylocopa  californica            744.70
#
#      HeadWidth_mm  BrM_mg_scaled     Nuclei     StDev       CV
# ...

# %% [markdown]
# **DataFrames are similar to Python dictionaries in that columns of a DataFrame can be selected by using the name of the column as a key.**

# %%
antBrainCellsDF['Nuclei']
# Out:
# 0        21578.0
# 1        22208.0
# 2        55575.0
# 3        60288.0
# 4        66463.0
#          ...
# 517    1349075.0
# 518    1460550.0
# 519          NaN
# 520          NaN
# 521          NaN
# Name: Nuclei, Length: 522, dtype: float64

# %% [markdown]
# Accessing columns in this manner is also compatible with the head() function.

# %%
antBrainCellsDF['Nuclei'].head(10)
# Out:
# 0    21578.0
# 1    22208.0
# 2    55575.0
# 3    60288.0
# 4    66463.0
# 5    68900.0
# 6    69588.0
# 7    70245.0
# 8    71775.0
# 9    73288.0
# Name: Nuclei, dtype: float64

# %% [markdown]
# **The to_csv() function will export a DataFrame as a .csv file. To work, it must be passed a string argument which represents the name of the file to export.**
#
# Files output by Python or any other program will appear in the `/content/` folder (aka. directory) of Google Colab by default. Verify that the file appears in the lefthand tab like below.

# %%
antBrainCellsDF.to_csv('antBrainCells.csv')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Loading in additional practice data**

# %% [markdown]
# ### Import the Pandas library.

# %%
import pandas as pd

# %% [markdown]
# ###Load the test_data.csv file from Lecture 1 as a Pandas DataFrame named "df".

# %%
df=pd.read_csv('https://raw.githubusercontent.com/Mangul-Lab-USC/biomedical_data_science/master/workshop_materials/test_data.csv')

# %% [markdown]
# ###This DataFrame has six columns and one column for sample names (Sample_Name).

# %%
df
# Out:
#   disease_status disease_severity  days_since_symptom_onset  age     sex  \
# 0       COVID-19           Severe                      15.0   75  female
# 1       COVID-19         Moderate                       9.0   47  female
# 2       COVID-19           Severe                      16.0   59    male
# 3        Healthy              NaN                       NaN   84  female
#
#         source_name   Sample_Name
# 0  single cell mRNA     nCOV3EUHM
# 1  single cell mRNA  nCOV0029EUHM
# 2      antibody tag     nCOV6EUHM
# 3  single cell mRNA           280

# %% [markdown]
# ###However, since we want to understand our data relative to each sample, reload the data with the sample_name column as the index column.

# %%
df=pd.read_csv('https://raw.githubusercontent.com/Mangul-Lab-USC/biomedical_data_science/master/workshop_materials/test_data.csv', index_col='Sample_Name')
df
# Out:
#              disease_status disease_severity  days_since_symptom_onset  age  \
# Sample_Name
# nCOV3EUHM          COVID-19           Severe                      15.0   75
# nCOV0029EUHM       COVID-19         Moderate                       9.0   47
# nCOV6EUHM          COVID-19           Severe                      16.0   59
# 280                 Healthy              NaN                       NaN   84
#
#                  sex       source_name
# Sample_Name
# nCOV3EUHM     female  single cell mRNA
# nCOV0029EUHM  female  single cell mRNA
# nCOV6EUHM       male      antibody tag
# 280           female  single cell mRNA

# %% [markdown]
# ###Now our data appears to contain two columns of strings and three columns of numbers. Confirm this as follows.
# Notice that here strings are labeled 'object' and the numbers are labeled 'float64'. If our data contained integers, they would be labled as 'int64'.

# %%
df.dtypes
# Out:
# disease_status               object
# disease_severity             object
# days_since_symptom_onset    float64
# age                           int64
# sex                          object
# source_name                  object
# dtype: object

# %% [markdown]
# ##**Selecting Data**

# %% [markdown]
# ###Select an arbritrary column.

# %%
df['disease_status']
# Out:
# Sample_Name
# nCOV3EUHM       COVID-19
# nCOV0029EUHM    COVID-19
# nCOV6EUHM       COVID-19
# 280              Healthy
# Name: disease_status, dtype: object

# %% [markdown]
# ###Select multiple columns using a Python List.
# Notice how indexing df with a list produces different output than indexing it with a string.

# %%
columnsOfInterest=['disease_status','disease_severity','age']
df[['disease_status','disease_severity','age']]
# Out:
#              disease_status disease_severity  age
# Sample_Name
# nCOV3EUHM          COVID-19           Severe   75
# nCOV0029EUHM       COVID-19         Moderate   47
# nCOV6EUHM          COVID-19           Severe   59
# 280                 Healthy              NaN   84

# %% [markdown]
# ###Select the first five rows from the start of a DataFrame.
# Note that because this DataFrame contains less than five rows, calling head() outputs the entire DataFrame. As such, it is useful for viewing the column names of large tabular records.

# %%
df.head(2)
# Out:
#              disease_status disease_severity  days_since_symptom_onset  age  \
# Sample_Name
# nCOV3EUHM          COVID-19           Severe                      15.0   75
# nCOV0029EUHM       COVID-19         Moderate                       9.0   47
#
#                  sex       source_name
# Sample_Name
# nCOV3EUHM     female  single cell mRNA
# nCOV0029EUHM  female  single cell mRNA

# %% [markdown]
# ###Select rows that match specific criteria.
# Notice that we use the "==" syntax here to denote "is equal to" instead of "=".

# %%
df.loc[df['disease_status'] == 'COVID-19']
# Out:
#              disease_status disease_severity  days_since_symptom_onset  age  \
# Sample_Name
# nCOV3EUHM          COVID-19           Severe                      15.0   75
# nCOV0029EUHM       COVID-19         Moderate                       9.0   47
# nCOV6EUHM          COVID-19           Severe                      16.0   59
#
#                  sex       source_name
# Sample_Name
# nCOV3EUHM     female  single cell mRNA
# nCOV0029EUHM  female  single cell mRNA
# nCOV6EUHM       male      antibody tag

# %% [markdown]
# Python also supports other comparison operators such as >, <, >=, <=, and != ("not equal to").

# %%
df.loc[df['age'] > 50]
# Out:
#             disease_status disease_severity  days_since_symptom_onset  age  \
# Sample_Name
# nCOV3EUHM         COVID-19           Severe                      15.0   75
# nCOV6EUHM         COVID-19           Severe                      16.0   59
# 280                Healthy              NaN                       NaN   84
#
#                 sex       source_name
# Sample_Name
# nCOV3EUHM    female  single cell mRNA
# nCOV6EUHM      male      antibody tag
# 280          female  single cell mRNA

# %% [markdown]
# ###Select rows that match multiple criteria.

# %%
df.loc[(df['disease_status'] == 'COVID-19') & (df['age'] > 50)]
# Out:
#             disease_status disease_severity  days_since_symptom_onset  age  \
# Sample_Name
# nCOV3EUHM         COVID-19           Severe                      15.0   75
# nCOV6EUHM         COVID-19           Severe                      16.0   59
#
#                 sex       source_name
# Sample_Name
# nCOV3EUHM    female  single cell mRNA
# nCOV6EUHM      male      antibody tag

# %% [markdown]
# ##**Creating New Columns**

# %% [markdown]
# ###Create a new column from existing string-containing columns.
# Note this is done by indexing df with a column the does not yet exist.

# %%
df['combinedDisease'] = df['disease_severity'] + ' ' + df['disease_status']
df
# Out:
#              disease_status disease_severity  days_since_symptom_onset  age  \
# Sample_Name
# nCOV3EUHM          COVID-19           Severe                      15.0   75
# nCOV0029EUHM       COVID-19         Moderate                       9.0   47
# nCOV6EUHM          COVID-19           Severe                      16.0   59
# 280                 Healthy              NaN                       NaN   84
#
#                  sex       source_name    combinedDisease
# Sample_Name
# nCOV3EUHM     female  single cell mRNA    Severe COVID-19
# nCOV0029EUHM  female  single cell mRNA  Moderate COVID-19
# nCOV6EUHM       male      antibody tag    Severe COVID-19
# 280           female  single cell mRNA                NaN

# %% [markdown]
# ### If the column already exists, the data in that column will be overwritten.

# %%
df['combinedDisease'] = df['disease_severity'] + '_' + df['disease_status']
df
# Out:
#              disease_status disease_severity  days_since_symptom_onset  age  \
# Sample_Name
# nCOV3EUHM          COVID-19           Severe                      15.0   75
# nCOV0029EUHM       COVID-19         Moderate                       9.0   47
# nCOV6EUHM          COVID-19           Severe                      16.0   59
# 280                 Healthy              NaN                       NaN   84
#
#                  sex       source_name    combinedDisease
# Sample_Name
# nCOV3EUHM     female  single cell mRNA    Severe_COVID-19
# nCOV0029EUHM  female  single cell mRNA  Moderate_COVID-19
# nCOV6EUHM       male      antibody tag    Severe_COVID-19
# 280           female  single cell mRNA                NaN

# %% [markdown]
# ###If you accidentally try to add strings and numbers together, you will receive the following error:

# %% [markdown]
# ![2vPPh0XE@2x.png](data:image/png;base64,...)

# %% [markdown]
# ###Create a new column based on a condition.
# Additionally, rows which did not meet the critera were not given a value so they defaulted to NaN.

# %%
df.loc[df['source_name'] == 'single cell mRNA', 'source'] = 'mRNA'
df
# Out:
#              disease_status disease_severity  days_since_symptom_onset  age  \
# Sample_Name
# nCOV3EUHM          COVID-19           Severe                      15.0   75
# nCOV0029EUHM       COVID-19         Moderate                       9.0   47
# nCOV6EUHM          COVID-19           Severe                      16.0   59
# 280                 Healthy              NaN                       NaN   84
#
#                  sex       source_name    combinedDisease source
# Sample_Name
# nCOV3EUHM     female  single cell mRNA    Severe_COVID-19   mRNA
# nCOV0029EUHM  female  single cell mRNA  Moderate_COVID-19   mRNA
# nCOV6EUHM       male      antibody tag    Severe_COVID-19    NaN
# 280           female  single cell mRNA                NaN   mRNA

# %%
df.loc[df['source_name'] == 'single cell mRNA']
# Out:
#              disease_status disease_severity  days_since_symptom_onset  age  \
# Sample_Name
# nCOV3EUHM          COVID-19           Severe                      15.0   75
# nCOV0029EUHM       COVID-19         Moderate                       9.0   47
# 280                 Healthy              NaN                       NaN   84
#
#                  sex       source_name    combinedDisease source
# Sample_Name
# nCOV3EUHM     female  single cell mRNA    Severe_COVID-19   mRNA
# nCOV0029EUHM  female  single cell mRNA  Moderate_COVID-19   mRNA
# 280           female  single cell mRNA                NaN   mRNA

# %% [markdown]
# ###Create a new column based on multiple conditions.

# %%
df.loc[(df['disease_severity'] == 'Severe') & (df['age'] > 66), 'senior_severity'] = "severeSenior"
df
# Out:
#              disease_status disease_severity  days_since_symptom_onset  age  \
# Sample_Name
# nCOV3EUHM          COVID-19           Severe                      15.0   75
# nCOV0029EUHM       COVID-19         Moderate                       9.0   47
# nCOV6EUHM          COVID-19           Severe                      16.0   59
# 280                 Healthy              NaN                       NaN   84
#
#                  sex       source_name    combinedDisease source  \
# Sample_Name
# nCOV3EUHM     female  single cell mRNA    Severe_COVID-19   mRNA
# nCOV0029EUHM  female  single cell mRNA  Moderate_COVID-19   mRNA
# nCOV6EUHM       male      antibody tag    Severe_COVID-19    NaN
# 280           female  single cell mRNA                NaN   mRNA
#
#              senior_severity
# Sample_Name
# nCOV3EUHM       severeSenior
# nCOV0029EUHM             NaN
# nCOV6EUHM                NaN
# 280                      NaN

# %% [markdown]
# ##**Cleaning Data of NaNs**

# %% [markdown]
# ### Load a version of the previous data containing a typo.
# Notice the error in `days_since_symptom_onset` for the sample, `nCOV6EUHM`.

# %%
dfWithTypo=pd.read_csv('https://raw.githubusercontent.com/Mangul-Lab-USC/biomedical_data_science/master/workshop_materials/test_data_typo.csv', index_col='Sample_Name')
dfWithTypo
# Out:
#              disease_status disease_severity days_since_symptom_onset  age  \
# Sample_Name
# nCOV3EUHM          COVID-19           Severe                       15   75
# nCOV0029EUHM       COVID-19         Moderate                        9   47
# nCOV6EUHM          COVID-19           Severe                       l6   59
# 280                 Healthy              NaN                      NaN   84
#
#                  sex       source_name
# Sample_Name
# nCOV3EUHM     female  single cell mRNA
# nCOV0029EUHM  female  single cell mRNA
# nCOV6EUHM       male      antibody tag
# 280           female  single cell mRNA

# %% [markdown]
# ### Check the impact of the typo on the `days_since_symptom_onset`.
# The data type in `days_since_symptom_onset` has changed from `float64` to `object`.
#
# Note that if this typo were at the end of a much larger DataFrame, we might not have caught it without calling dtypes.

# %%
dfWithTypo.dtypes
# Out:
# disease_status              object
# disease_severity            object
# days_since_symptom_onset    object
# age                          int64
# sex                         object
# source_name                 object
# dtype: object

# %% [markdown]
# ###Convert all typos in `days_since_symptom_onset` into a NaN value.

# %%
dfWithTypo['days_since_symptom_onset'] = pd.to_numeric(dfWithTypo['days_since_symptom_onset'], errors='coerce')
dfWithTypo
# Out:
#              disease_status disease_severity  days_since_symptom_onset  age  \
# Sample_Name
# nCOV3EUHM          COVID-19           Severe                      15.0   75
# nCOV0029EUHM       COVID-19         Moderate                       9.0   47
# nCOV6EUHM          COVID-19           Severe                       NaN   59
# 280                 Healthy              NaN                       NaN   84
#
#                  sex       source_name
# Sample_Name
# nCOV3EUHM     female  single cell mRNA
# nCOV0029EUHM  female  single cell mRNA
# nCOV6EUHM       male      antibody tag
# 280           female  single cell mRNA

# %% [markdown]
# ### You can confirm that the invalid value was succesfully converted into an NaN by using isnull().

# %% [markdown]
# ###Display whether the values in `days_since_symptom_onset` are NaNs.
# Note that for a much larger DataFrame, you can add '*.sum()*' to count NaNs.

# %%
dfWithTypo['days_since_symptom_onset'].isnull()
# Out:
# Sample_Name
# nCOV3EUHM       False
# nCOV0029EUHM    False
# nCOV6EUHM        True
# 280              True
# Name: days_since_symptom_onset, dtype: bool

# %% [markdown]
# ###Remove all rows that contain any NaN values.

# %%
dfWithTypoRemoved=dfWithTypo.dropna(how='any')
dfWithTypoRemoved
# Out:
#              disease_status disease_severity  days_since_symptom_onset  age  \
# Sample_Name
# nCOV3EUHM          COVID-19           Severe                      15.0   75
# nCOV0029EUHM       COVID-19         Moderate                       9.0   47
#
#                  sex       source_name
# Sample_Name
# nCOV3EUHM     female  single cell mRNA
# nCOV0029EUHM  female  single cell mRNA

# %% [markdown]
# ###Alternatively, replace NaN values with a specific value.

# %%
dfWithTypoReplaced=dfWithTypo.fillna('not valid')
dfWithTypoReplaced
# Out:
#              disease_status disease_severity days_since_symptom_onset  age  \
# Sample_Name
# nCOV3EUHM          COVID-19           Severe                     15.0   75
# nCOV0029EUHM       COVID-19         Moderate                      9.0   47
# nCOV6EUHM          COVID-19           Severe                not valid   59
# 280                 Healthy        not valid                not valid   84
#
#                  sex       source_name
# Sample_Name
# nCOV3EUHM     female  single cell mRNA
# nCOV0029EUHM  female  single cell mRNA
# nCOV6EUHM       male      antibody tag
# 280           female  single cell mRNA

# %% [markdown]
# ### However, if you want to permit some NaN values, you may do so in the following ways.

# %% [markdown]
# ###Append an empty row to the previous DataFrame for example's sake.
# Note: You do not need to know this command for this lab since it is used here for example purposes only.

# %%
dfWithAddedNaNs=df.append(pd.Series(name='exampleRow', dtype='object'))
dfWithAddedNaNs
# Out:
# <ipython-input-43-096d283537a5>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfWithAddedNaNs=df.append(pd.Series(name='exampleRow', dtype='object'))
#              disease_status disease_severity  days_since_symptom_onset   age  \
# Sample_Name
# nCOV3EUHM          COVID-19           Severe                      15.0  75.0
# nCOV0029EUHM       COVID-19         Moderate                       9.0  47.0
# nCOV6EUHM          COVID-19           Severe                      16.0  59.0
# 280                 Healthy              NaN                       NaN  84.0
# exampleRow              NaN              NaN                       NaN   NaN
#
#                  sex       source_name    combinedDisease source  \
# Sample_Name
# nCOV3EUHM     female  single cell mRNA    Severe_COVID-19   mRNA
# nCOV0029EUHM  female  single cell mRNA  Moderate_COVID-19   mRNA
# ...

# %% [markdown]
# ###Remove rows entirely made up of NaNs.

# %%
dfWithAddedNaNs.dropna(how='all')
# Out:
#              disease_status disease_severity  days_since_symptom_onset   age  \
# Sample_Name
# nCOV3EUHM          COVID-19           Severe                      15.0  75.0
# nCOV0029EUHM       COVID-19         Moderate                       9.0  47.0
# nCOV6EUHM          COVID-19           Severe                      16.0  59.0
# 280                 Healthy              NaN                       NaN  84.0
#
#                  sex       source_name    combinedDisease source  \
# Sample_Name
# nCOV3EUHM     female  single cell mRNA    Severe_COVID-19   mRNA
# nCOV0029EUHM  female  single cell mRNA  Moderate_COVID-19   mRNA
# nCOV6EUHM       male      antibody tag    Severe_COVID-19    NaN
# 280           female  single cell mRNA                NaN   mRNA
#
#              senior_severity
# Sample_Name
# nCOV3EUHM       severeSenior
# nCOV0029EUHM             NaN
# nCOV6EUHM                NaN
# 280                      NaN

# %% [markdown]
# ###Remove rows containing NaN in new_column0

# %%
dfWithAddedNaNs.dropna(subset=['disease_severity'])
# Out:
#              disease_status disease_severity  days_since_symptom_onset   age  \
# Sample_Name
# nCOV3EUHM          COVID-19           Severe                      15.0  75.0
# nCOV0029EUHM       COVID-19         Moderate                       9.0  47.0
# nCOV6EUHM          COVID-19           Severe                      16.0  59.0
#
#                  sex       source_name    combinedDisease source  \
# Sample_Name
# nCOV3EUHM     female  single cell mRNA    Severe_COVID-19   mRNA
# nCOV0029EUHM  female  single cell mRNA  Moderate_COVID-19   mRNA
# nCOV6EUHM       male      antibody tag    Severe_COVID-19    NaN
#
#              senior_severity
# Sample_Name
# nCOV3EUHM       severeSenior
# nCOV0029EUHM             NaN
# nCOV6EUHM                NaN

# %% [markdown]
# ##**Merging Multiple DataFrames**

# %% [markdown]
# ###Import the Pandas library.

# %%
import pandas as pd

# %% [markdown]
# ###Load the first DataFrame.

# %%
df=pd.read_csv('https://raw.githubusercontent.com/Mangul-Lab-USC/biomedical_data_science/master/workshop_materials/test_data.csv', index_col='Sample_Name')
df
# Out:
#              disease_status disease_severity  days_since_symptom_onset  age  \
# Sample_Name
# nCOV3EUHM          COVID-19           Severe                      15.0   75
# nCOV0029EUHM       COVID-19         Moderate                       9.0   47
# nCOV6EUHM          COVID-19           Severe                      16.0   59
# 280                 Healthy              NaN                       NaN   84
#
#                  sex       source_name
# Sample_Name
# nCOV3EUHM     female  single cell mRNA
# nCOV0029EUHM  female  single cell mRNA
# nCOV6EUHM       male      antibody tag
# 280           female  single cell mRNA

# %% [markdown]
# ###Load a second DataFrame.

# %%
df2=pd.read_csv('https://raw.githubusercontent.com/Mangul-Lab-USC/biomedical_data_science/master/workshop_materials/test_data2.csv', index_col='Sample_Name')
df2
# Out:
#                  Bases
# Sample_Name
# nCOV6EUHM     263.91 k
# 280             4.10 G
# nCOV0029EUHM    3.76 G

# %% [markdown]
# ###Merge two DataFrames based on a specific column.
# Notice that sample2 was removed. This is because by default (how='inner'), Pandas merges DataFrames based on row identifiers that only appear in both DataFrames. In this case, sample2 was only in df.

# %% [markdown]
# ![KXlJPBNL@2x.png](data:image/png;base64,...)

# %% [markdown]
# Intersection of two sets (A∩B)

# %%
df1And2=df.merge(df2,on='Sample_Name')
df1And2
# Out:
#              disease_status disease_severity  days_since_symptom_onset  age  \
# Sample_Name
# nCOV0029EUHM       COVID-19         Moderate                       9.0   47
# nCOV6EUHM          COVID-19           Severe                      16.0   59
# 280                 Healthy              NaN                       NaN   84
#
#                  sex       source_name     Bases
# Sample_Name
# nCOV0029EUHM  female  single cell mRNA    3.76 G
# nCOV6EUHM       male      antibody tag  263.91 k
# 280           female  single cell mRNA    4.10 G

# %%
df1And2=df.merge(df2,on='Sample_Name',how='inner')
df1And2
# Out:
#              disease_status disease_severity  days_since_symptom_onset  age  \
# Sample_Name
# nCOV0029EUHM       COVID-19         Moderate                       9.0   47
# nCOV6EUHM          COVID-19           Severe                      16.0   59
# 280                 Healthy              NaN                       NaN   84
#
#                  sex       source_name     Bases
# Sample_Name
# nCOV0029EUHM  female  single cell mRNA    3.76 G
# nCOV6EUHM       male      antibody tag  263.91 k
# 280           female  single cell mRNA    4.10 G

# %% [markdown]
# ###Alternatively, merge two DataFrames based on row identifiers that appear in the left DataFrame.
# Notice that sample2 is now included again. Merging via the 'right' DataFrame instead would remove sample2 once more.

# %% [markdown]
# ![sbmIRgYV@2x.png](data:image/png;base64,...)

# %%
df1And2MergedLeft=df.merge(df2,on='Sample_Name',how='left')
df1And2MergedLeft
# Out:
#              disease_status disease_severity  days_since_symptom_onset  age  \
# Sample_Name
# nCOV3EUHM          COVID-19           Severe                      15.0   75
# nCOV0029EUHM       COVID-19         Moderate                       9.0   47
# nCOV6EUHM          COVID-19           Severe                      16.0   59
# 280                 Healthy              NaN                       NaN   84
#
#                  sex       source_name     Bases
# Sample_Name
# nCOV3EUHM     female  single cell mRNA       NaN
# nCOV0029EUHM  female  single cell mRNA    3.76 G
# nCOV6EUHM       male      antibody tag  263.91 k
# 280           female  single cell mRNA    4.10 G

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Alternatively, merge two DataFrames including all row identifiers from both DataFrames.
# Here, we added an empty row to df2 and saved it under the name df2Altered. Even though the empty row was not present in df, it was still included because we merged based on the unison of both DataFrames.

# %% [markdown]
# ![1NWuFueX@2x.png](data:image/png;base64,...)

# %% [markdown]
# Union of two sets (A∪B)

# %%
df2Altered=df2.append(pd.Series(name='NaNRow',dtype='object'))
df2Altered
# Out:
# <ipython-input-52-12c35a67fc5d>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2Altered=df2.append(pd.Series(name='NaNRow',dtype='object'))
#                  Bases
# Sample_Name
# nCOV6EUHM     263.91 k
# 280             4.10 G
# nCOV0029EUHM    3.76 G
# NaNRow             NaN

# %%
df1And2AlteredMerged=df.merge(df2Altered,on='Sample_Name',how='outer')
df1And2AlteredMerged
# Out:
#              disease_status disease_severity  days_since_symptom_onset   age  \
# Sample_Name
# nCOV3EUHM          COVID-19           Severe                      15.0  75.0
# nCOV0029EUHM       COVID-19         Moderate                       9.0  47.0
# nCOV6EUHM          COVID-19           Severe                      16.0  59.0
# 280                 Healthy              NaN                       NaN  84.0
# NaNRow                  NaN              NaN                       NaN   NaN
#
#                  sex       source_name     Bases
# Sample_Name
# nCOV3EUHM     female  single cell mRNA       NaN
# nCOV0029EUHM  female  single cell mRNA    3.76 G
# nCOV6EUHM       male      antibody tag  263.91 k
# 280           female  single cell mRNA    4.10 G
# NaNRow           NaN               NaN       NaN

# %% [markdown]
# ###Load a third DataFrame.
# Note that this third DataFrame has a column1 just like df.

# %%
df3=pd.read_csv('https://raw.githubusercontent.com/Mangul-Lab-USC/biomedical_data_science/master/workshop_materials/test_data3.csv', index_col='Sample_Name')
df3
# Out:
#                  Bases  days_since_symptom_onset
# Sample_Name
# nCOV6EUHM     263.91 k                        16
# 280             4.10 G                         0
# nCOV0029EUHM    3.76 G                         9

# %% [markdown]
# ###Merge two DataFrames that contain multiple columns with the same name.
# Notice that instead of choosing df or df3's version of column1, both were saved and automatically renamed.

# %%
df1And2=df.merge(df3,on='Sample_Name')
df1And2
# Out:
#              disease_status disease_severity  days_since_symptom_onset_x  age  \
# Sample_Name
# nCOV0029EUHM       COVID-19         Moderate                         9.0   47
# nCOV6EUHM          COVID-19           Severe                        16.0   59
# 280                 Healthy              NaN                         NaN   84
#
#                  sex       source_name     Bases  days_since_symptom_onset_y
# Sample_Name
# nCOV0029EUHM  female  single cell mRNA    3.76 G                           9
# nCOV6EUHM       male      antibody tag  263.91 k                          16
# 280           female  single cell mRNA    4.10 G                           0

# %% [markdown]
# ##**Grouping Rows**

# %% [markdown]
# ###Group rows based on a single column.
# Notice how the *sample_name* column was removed because Pandas could not generate the mean of multiple names.
#
# You can also group rows by sum using sum() instead of mean().

# %%
df1And2_groupedBySex=df1And2.groupby('sex').mean()
df1And2_groupedBySex
# Out:
# <ipython-input-56-eb8e3f562519>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1And2_groupedBySex=df1And2.groupby('sex').mean()
#         days_since_symptom_onset_x   age  days_since_symptom_onset_y
# sex
# female                         9.0  65.5                         4.5
# male                          16.0  59.0                        16.0

# %% [markdown]
# ###Group rows based on multiple columns.

# %%
df1And2_groupedBySexAndDiseaseStatus=df1And2.groupby(['disease_status','sex']).mean()
df1And2_groupedBySexAndDiseaseStatus
# Out:
# <ipython-input-57-4d74fa4fd07d>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1And2_groupedBySexAndDiseaseStatus=df1And2.groupby(['disease_status','sex']).mean()
#                        days_since_symptom_onset_x   age  \
# disease_status sex
# COVID-19       female                         9.0  47.0
#                male                          16.0  59.0
# Healthy        female                         NaN  84.0
#
#                        days_since_symptom_onset_y
# disease_status sex
# COVID-19       female                         9.0
#                male                          16.0
# Healthy        female                         0.0

# %% [markdown]
# Notice how both of the above examples set new index columns, rendering those columns inaccessible. To perform futher manipulations on those columns, you will need to reset the DataFrame's index columns.

# %% [markdown]
# ###Reset a DataFrame's index column.

# %%
df1And2_groupedBySexAndDiseaseStatus=df1And2_groupedBySexAndDiseaseStatus.reset_index()
df1And2_groupedBySexAndDiseaseStatus
# Out:
#   disease_status     sex  days_since_symptom_onset_x   age  \
# 0       COVID-19  female                         9.0  47.0
# 1       COVID-19    male                        16.0  59.0
# 2        Healthy  female                         NaN  84.0
#
#    days_since_symptom_onset_y
# 0                         9.0
# 1                        16.0
# 2                         0.0

# %% [markdown]
# Afterwards, you can set a new index column should you so choose.

# %% [markdown]
# ###Set a new index column for a DataFrame.

# %%
df1And2_groupedBySexAndDiseaseStatus=df1And2_groupedBySexAndDiseaseStatus.set_index('disease_status')
df1And2_groupedBySexAndDiseaseStatus
# Out:
#                    sex  days_since_symptom_onset_x   age  \
# disease_status
# COVID-19        female                         9.0  47.0
# COVID-19          male                        16.0  59.0
# Healthy         female                         NaN  84.0
#
#                 days_since_symptom_onset_y
# disease_status
# COVID-19                               9.0
# COVID-19                              16.0
# Healthy                                0.0

# %% [markdown]
# ## **Additional Pandas functions and DataFrame methods**

# %% [markdown]
# While the tutorial in this and the previous assignment covers the basics of Pandas, the library is capable of far more.
#
# For an accessible overview of Pandas other functionalities, refer to the following documents:
#
# - **Pandas in 10 minutes:** https://pandas.pydata.org/docs/user_guide/10min.html#min
#
# - **Pandas code cookbook:** https://pandas.pydata.org/docs/user_guide/cookbook.html#cookbook

# %% [markdown]
# # **Using ChatGPT to to learn new Python libraries**
# ChatGPT is a powerful instrument that can be used to boost your understanding of python programming language.
# In this section we will access the stand-alone browser version of it to receive some answers related to todays topic.

# %% [markdown]
# **If you would like to explore Pandas' functions further, here are comprehensive lists of the functions available in the Pandas library:**
#
#
# *General Functions*
#
# https://pandas.pydata.org/docs/reference/general_functions.html
#
#
# *DataFrame Methods*
#
# https://pandas.pydata.org/docs/reference/frame.html

# %% [markdown]
# ### Accessing ChatGPT
# Follow the link:
#
# https://chat.openai.com/
#
# Sign-up and login using your gmail account.

# %% [markdown]
# **Explaining programming concepts**
#
# ChatGPT can help clarify programming concepts, such as data structures, algorithms, control structures, and object-oriented programming principles, by providing clear and concise explanations.
#
# *Example: "Can you explain the concept of recursion in programming?*

# %% [markdown]
# **Syntax guidance**
#
# ChatGPT can assist with understanding the correct syntax for various programming languages, including Python, JavaScript, and others. This can be especially helpful for beginners who may struggle with syntax rules.
#
# *Example: "What is the correct syntax for defining a function in Python which counts the number of digits in a number?"*

# %% [markdown]
# **Debugging assistance**
#
# ChatGPT can help identify and resolve errors in code. Users can provide a specific query describing the issue, along with relevant code snippets, and ChatGPT will suggest possible solutions or explanations for the error.
#
# *Example: I'm getting a 'TypeError: unsupported operand type(s) for +: 'int' and 'str'' error in my Python code. What could be causing this?*

# %% [markdown]
# **Code generation and optimization**
#
# ChatGPT can offer guidance on programming best practices and code optimization, such as writing clean, efficient, and maintainable code. Additionaly it can generate code snippets based on user queries or descriptions of the desired functionality. This feature can save time and effort, especially for repetitive or boilerplate code.
#
# *Example: Can you provide a Python code snippet to read a CSV file using the pandas library?*

# %% [markdown]
# **Code exploration**
#
#  You can provide code snippets or specific lines of code, and ChatGPT will help you understand the purpose and functionality of the code. This can be particularly useful for beginners who are learning Python or for experienced developers looking to understand unfamiliar code.
#
#  *Example: Explain the following code:*
#
#
#
# ```
#  def count_digits(number):
#
#     return len(str(abs(number)))
# ```

# %% [markdown]
# #**Hands-on Assignment 2: Introduction to Pandas and Large Language Model (LLM)-assisted coding**

# %% [markdown]
# ##**Introduction**

# %% [markdown]
# Data cleaning and data manipulation are the first steps of most any analysis. They ensure that the data you analyze are of acceptable quality and that they are in the correct format for use in further applications.
#
# Here you will gain experience performing these steps with a real-world medical dataset to produce a modified version that hones in on specific aspects of the data.
#
# The data you will be using a dataset published by The National Heart, Lung and Blood Institute (NHLBI) from a clinical trial known as the Digitalis Investigation Group (DIG) Trial. This data contains baseline and outcome information for chronic heart failure patients from the DIG Trial cohort who received either the drug Digoxin or a placebo. Here, outcomes have been recorded under two main categories, cardiovasular mortality and hospitalization.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# For more information, you may refer to a comprehensive description of this dataset here:
#
# https://biolincc.nhlbi.nih.gov/media/teachingstudies/digdoc.pdf?link_time=2022-09-20_07:24:09.208947

# %% [markdown]
# ##**Instructions**

# %% [markdown]
# In your own Colab notebook, use the commands presented in the previous sections to perform the following DataFrame manipulations using Pandas. You will be graded based on whether your Colab notebook can modify the DataFrame according to the steps below and export it as a .csv file.

# %% [markdown]
# ##**Steps**
#
# To start, import this dataset as a Pandas DataFrame using this direct link to this dataset:
#
# https://drive.google.com/uc?export=download&id=1M0ZFQ09JPZGPm0cVJ0gXwENSgwf84cd2

# %%
import pandas as pd
df = pd.read_csv('https://drive.google.com/uc?export=download&id=1M0ZFQ09JPZGPm0cVJ0gXwENSgwf84cd2')
df
# Out:
#         ID  TRTMT  AGE  RACE  SEX  EJF_PER  EJFMETH  CHESTX     BMI  KLEVEL  \
# 0        1      0   66     1    1       40        2    0.50  20.073     NaN
# 1        2      0   77     1    1       12        1    0.56  20.701     3.1
# 2        3      0   72     1    2       36        1    0.68  25.530     5.1
# 3        4      1   57     1    1       31        1    0.48  25.794     NaN
# 4        5      0   74     1    1       15        1    0.53  25.654     4.0
# ...    ...    ...  ...   ...  ...      ...      ...     ...     ...     ...
# 6795  6796      0   73     1    1       23        1    0.58  28.975     NaN
# 6796  6797      1   39     1    1       15        1    0.46  22.097     4.0
# 6797  6798      1   55     1    1       23        1    0.62  26.221     NaN
# 6798  6799      1   56     1    1       29        1    0.44  26.651     4.3
# 6799  6800      0   70     1    1       45        3    0.44  24.374     5.1
#
# ...

# %% [markdown]
# After obtaining a new dataset, it is important get a sense for what information it contains. Start by viewing just the beginning of the file.

# %%
df.head()
# Out:
#    ID  TRTMT  AGE  RACE  SEX  EJF_PER  EJFMETH  CHESTX     BMI  KLEVEL  ...  \
# 0   1      0   66     1    1       40        2    0.50  20.073     NaN  ...
# 1   2      0   77     1    1       12        1    0.56  20.701     3.1  ...
# 2   3      0   72     1    2       36        1    0.68  25.530     5.1  ...
# 3   4      1   57     1    1       31        1    0.48  25.794     NaN  ...
# 4   5      0   74     1    1       15        1    0.53  25.654     4.0  ...
#
#    OTH  OTHDAYS  HOSP  HOSPDAYS  NHOSP  DEATH  DEATHDAY  REASON  DWHF  \
# 0    1      533     1       533      6      0      1438     NaN     1
# 1    1      880     1       468      4      1      1360     1.0     1
# 2    0     1391     1       631      2      0      1391     NaN     1
# 3    0     1157     0      1157      0      0      1157     NaN     0
# 4    1      459     1       191      5      0      1550     NaN     1
#
#    DWHFDAYS
# 0      1379
# 1      1329
# 2       631
# 3      1157
# 4       191
#
# ...

# %% [markdown]
# Of note, here are the columns we will be focusing on for this assignment. Start by creating a Python list containing the name of these columns of interest.
#
# ・age (*`AGE`*)
#
# ・whether they were white or nonwhite (*`RACE`*)
#
# ・sex (*`SEX`*)
#
# ・percent Ejection Fraction (*`EJF_PER`*)
#
# ・Serum Creatinine Level (*`CREAT`*)
#
# ・Serum Potassium Level (*`KLEVEL`*)
#
# ・Approximate duration of Congestive Heart Failure (*`CHFDUR`*)
#
# ・Etiology of Congestive Heart Failure (*`CHFETIOL`*)
#
# ・Previous Myocardial Infarction (*`PREVMI`*)
#
# ・History of Diabetes (*`DIABETES`*)
#
# ・History of Hypertension (*`HYPERTEN`*)
#
# ・Dose of Digoxin/placebo Prescribed (mg/day) (*`DIGDOSE`*)
#
# ・Cardiovascular Disease Hospitalization (*`CVD`*)
#
# ・Worsening Heart Failure (*`WHF`*)
#
# ・Digoxin Toxicity (*`DIG`*)
#
# ・First Hospitalization for any reason (*`HOSP`*)
#
# ・Number of Hospitalizations (*`NHOSP`*)
#
# ・Death (*`DEATH`*)
#
# ・Reason for Death (*`REASON`*)

# %%
columns_of_interest = ['AGE','RACE','SEX','EJF_PER','CREAT','KLEVEL','CHFDUR','CHFETIOL','PREVMI','DIABETES','HYPERTEN','DIGDOSE','CVD','WHF','DIG','HOSP','NHOSP','DEATH','REASON']

# %% [markdown]
# Then, create a DataFrame with a new name that only contains those columns. If successful, calling its name should produce this output:

# %%
df_reduced = df[columns_of_interest]
df_reduced
# Out:
#       AGE  RACE  SEX  EJF_PER  CREAT  KLEVEL  CHFDUR  CHFETIOL  PREVMI  \
# 0      66     1    1       40  1.261     NaN    96.0       1.0     0.0
# 1      77     1    1       12  1.500     3.1     2.0       4.0     1.0
# 2      72     1    2       36  1.239     5.1    12.0       1.0     0.0
# 3      57     1    1       31  2.250     NaN    24.0       2.0     0.0
# 4      74     1    1       15  1.466     4.0   288.0       4.0     0.0
# ...   ...   ...  ...      ...    ...     ...     ...       ...     ...
# 6795   73     1    1       23  0.909     NaN    12.0       1.0     0.0
# 6796   39     1    1       15  1.500     4.0     3.0       2.0     0.0
# 6797   55     1    1       23  1.200     NaN     2.0       4.0     0.0
# 6798   56     1    1       29  1.273     4.3    11.0       1.0     1.0
# 6799   70     1    1       45  0.989     5.1     3.0       1.0     1.0
#
#       DIABETES  HYPERTEN  DIGDOSE  CVD  WHF  DIG  HOSP  NHOSP  DEATH  REASON
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Next, we will want to scan our new DataFrame for NaN values that may hinder later analyses. To do so, run the following code where `df_reduced` is the name of your reduced DataFrame.

# %%
nan_columns = df_reduced.isna().any()
print(nan_columns[nan_columns == True])
# Out:
# KLEVEL      True
# CHFDUR      True
# CHFETIOL    True
# PREVMI      True
# HYPERTEN    True
# DIGDOSE     True
# REASON      True
# dtype: bool

# %% [markdown]
# Based on this, we can see that there are NaN values in the DataFrame's *`KLEVEL`*, *`CHFDUR`*, *`CHFETIOL`*, *`PREVMI`*, *`HYPERTEN`*, *`DIGDOSE`*, and *`REASON`* columns.  Let's consider potentional reasons for these NaNs and figure out how we should deal with them.
#
# Since the *`KLEVEL`* and *`CHFDUR`* columns contain numeric measurements, let's delete any rows that contain NaN values in those columns as they may break downstream calculations.

# %%
df_reduced_cleaned=df_reduced.dropna(subset=['KLEVEL','CHFDUR'])
df_reduced_cleaned
# Out:
#       AGE  RACE  SEX  EJF_PER  CREAT  KLEVEL  CHFDUR  CHFETIOL  PREVMI  \
# 1      77     1    1       12  1.500     3.1     2.0       4.0     1.0
# 2      72     1    2       36  1.239     5.1    12.0       1.0     0.0
# 4      74     1    1       15  1.466     4.0   288.0       4.0     0.0
# 5      69     2    2       45  1.200     4.3    84.0       4.0     1.0
# 6      64     1    2       30  1.300     4.3    31.0       1.0     1.0
# ...   ...   ...  ...      ...    ...     ...     ...       ...     ...
# 6793   64     1    1       16  1.159     4.2    48.0       1.0     1.0
# 6794   62     1    1       20  1.398     4.9     2.0       4.0     1.0
# 6796   39     1    1       15  1.500     4.0     3.0       2.0     0.0
# 6798   56     1    1       29  1.273     4.3    11.0       1.0     1.0
# 6799   70     1    1       45  0.989     5.1     3.0       1.0     1.0
#
#       DIABETES  HYPERTEN  DIGDOSE  CVD  WHF  DIG  HOSP  NHOSP  DEATH  REASON
# ...

# %% [markdown]
# Afterwards, you should no longer see NaNs in the *`KLEVEL`* or *`CHFDUR`* columns. You can confirm this by running this line of code if the name of your cleaned DataFrame is `df_reduced_cleaned`.

# %%
df_reduced_cleaned.isnull().sum()
# Out:
# AGE            0
# RACE           0
# SEX            0
# EJF_PER        0
# CREAT          0
# KLEVEL         0
# CHFDUR         0
# CHFETIOL      17
# PREVMI         1
# DIABETES       0
# HYPERTEN       1
# DIGDOSE        1
# CVD            0
# WHF            0
# DIG            0
# HOSP           0
# NHOSP          0
# DEATH          0
# REASON      3899
# dtype: int64

# %% [markdown]
# As for the rest of the NaN values, since they are all strictly categorical, we can convert the NaN to the string 'Not given' and report it as such. in the rest of the columns, we will leave them untouched as those columns are strictly categorical and can be reported as such. For example, Etiology of Congestive Heart Failure could be Ischemic, Hypertensive, Valvular, Idiopathic, Alcohol related, other, or Not Given.

# %%
df_reduced_cleaned_replaced=df_reduced_cleaned.fillna('Not Given')
df_reduced_cleaned_replaced

# %% [markdown]
# You may run this line of code again to confirm that all NaN values have been taken care of.

# %%
df_reduced_cleaned_replaced.isnull().sum()

# %% [markdown]
# From here, we can make further manipulations to this DataFrame to look into specific subgroups of patients, such as all patients with a history of diabetes, all patients with a history of hypertension, and those with a history of both.
#
# To facilitate this comparison, let's create an additional column named `DIABETES_AND_HYPERTEN` that contains the value `1` if a patient has a history of both diabetes and hypertension, and `0` if they do not. To simplify calulation, `1` and `0` should be integers, not strings.
#
# Start by creating the new column with all cells contining the value of `0`.

# %%
df_reduced_cleaned_replaced['DIABETES_AND_HYPERTEN'] = 0
df_reduced_cleaned_replaced

# %% [markdown]
# Then, convert cells in the `DIABETES_AND_HYPERTEN` column for patients with a history of both Diabetes and Hypertension from `0` into `1`.
#
# ( Hint: Keep in mind what data types are stored in each column. )

# %%
df_reduced_cleaned_replaced.loc[(df_reduced_cleaned_replaced['DIABETES'] == 1) & (df_reduced_cleaned_replaced['HYPERTEN'] == 1), 'DIABETES_AND_HYPERTEN'] = 1
df_reduced_cleaned_replaced

# %% [markdown]
# If this was performed successfully, running the following code should output:
# ```
# 0    5202
# 1     783
# Name: DIABETES_AND_HYPERTEN, dtype: int64
# ```
#
# This says that 783 patients had a history of both diabetes and hypertension.

# %%
df_reduced_cleaned_replaced['DIABETES_AND_HYPERTEN'].value_counts()

# %% [markdown]
# With this modification made, we are now ready to export our tabular summary data. Hypothetically, this would be ready to store in the `Results` subdirectory of a GitHub repository.
#
# Export your final DataFrame in the code-block below:

# %%
df_reduced_cleaned_replaced.to_csv('summarydata.csv')

# %% [markdown]
# Congratulations! You've cleaned and reformatted this lesson's DIG Trial dataset into a format that is ready for exploratory data analysis, data visualization, and statistical analysis!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**Rubric (10 points)**

# %% [markdown]
# **2 points**
#
# A reduced DataFrame was created that contains only the 19 columns of interest: AGE, RACE, SEX, EJF_PER, CREAT, KLEVEL, CHFDUR, CHFETIOL, PREVMI, DIABETES,HYPERTEN, DIGDOSE, CVD, WHF, DIG, HOSP, NHOSP, DEATH, and REASON.
#
# ---
#
# **2 points**
#
# All rows that contained NaN values in the KLEVEL and CHFDUR columns were deleted.
#
# ---
#
# **1 point**
#
# After all rows that contained NaN values in the KLEVEL and CHFDUR columns were deleted, the rest of the NaN values were converted to the string, "Not given".
#
# ---
#
# **4 points**
#
# The final DataFrame contains an additional column named `DIABETES_AND_HYPERTEN` that contains the interger `1` if a patient has a history of both diabetes and hypertension, and the interger `0` if they do not.
#
# ---
#
# **1 point**
#
# A final DataFrame was exported to the `/content` directory.

# %%
a=['Nitesh','Mangul','Morgana']
a

# %%
a[0]

# %%
a[0][1]
